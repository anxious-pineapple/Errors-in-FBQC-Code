# %%
# !pip install qutip
# Out:
# Requirement already satisfied: qutip in c:\users\16yuk\anaconda3\lib\site-packages (4.6.2)
# Requirement already satisfied: scipy>=1.0 in c:\users\16yuk\anaconda3\lib\site-packages (from qutip) (1.5.2)
# Requirement already satisfied: numpy>=1.16.6 in c:\users\16yuk\anaconda3\lib\site-packages (from qutip) (1.19.2)
# Requirement already satisfied: packaging in c:\users\16yuk\anaconda3\lib\site-packages (from qutip) (20.4)
# Requirement already satisfied: pyparsing>=2.0.2 in c:\users\16yuk\anaconda3\lib\site-packages (from packaging->qutip) (2.4.7)
# Requirement already satisfied: six in c:\users\16yuk\anaconda3\lib\site-packages (from packaging->qutip) (1.15.0)

# %%
import qutip
import numpy as np
import matplotlib.pyplot as plt
from scipy.integrate import quad

# %%
#Defining the shape of the output pulse as a function of time
def v(t,args=None):
  return np.sqrt(gamma)*np.exp(-t*gamma/2)
  #return 0

#Defining |v(t)|^2 
def v_2(t):
  return np.conj(v(t))*v(t)

#Defining the time dependent coupling
def g(t, args):
  integral = quad(v_2, 0, t)[0]
  if integral == 0:
    return 0
  else:
    return -np.conj(v(t))/ ( integral**0.5 )

# %%
##    Defining All operators    ##

#Number of fock states in the output cavity
N = 2   

#Coupling constant         
gamma = 2

#Defining time of simulation
t = 500                                                                         #temporal resolution/ number of points taken
t_final = 20
times = np.linspace(0.1, t_final, t)


#Defining initial state of the system and cavity, with the system in excited state 
psi0 = qutip.tensor(qutip.fock(2,1), qutip.fock(N, 0))

#Anihilation operator of the cavity
a  = qutip.tensor(qutip.qeye(2), qutip.destroy(N))

#Lowering operator of the system
c = qutip.tensor(qutip.destroy(2), qutip.qeye(N))

Hs = a.dag()*a                                                                  #system hamiltonian
H = [ [ 0.5j*(gamma**0.5)*( (c.dag()*a)-(a.dag()*c) ) , g]]                     #Net time dependent Hamiltonian (Eq 5 in the Quantum Pulses paper)

L_0 = [ (gamma**0.5)*c, [a, g] ]                                                #Lindblad operator 0 (Eq 6)

I = qutip.tensor(qutip.qeye(2), qutip.qeye(N))

# %%
#Plotting out the output pulse and time dependent coupling
plt.plot(times, [v(t) for t in times]) 
plt.plot(times, [g(t, None) for t in times]) 
plt.xlabel('Time') 
plt.legend(("v(t)", "g_v(t)"))

# %%
result = qutip.mesolve(H, psi0, times, [L_0,], [c.dag()*c, a.dag()*a])          #Evolving the system , with output c*c and a*a

# %%
plt.figure() 
plt.plot(times, result.expect[0]) 
plt.plot(times, result.expect[1]) 
plt.xlabel('Time') 
plt.ylabel('Expectation values') 
plt.legend(("atom excitation probability", "cavity photon number")) 
plt.plot([times[0], times[-1]], [result.expect[0][-1], result.expect[0][-1]],'--')
plt.plot([times[0], times[-1]], [result.expect[1][-1], result.expect[1][-1]],'--')
plt.show() 
gamma
# Out:
# 2

# %% [markdown]
# ---
# ---
# # Calculating probability lost ie <L_o*L_o>:

# %%
I_0 = list()
result_states = qutip.mesolve(H, psi0, times, [L_0,], [])                      #Evolving the system , with output of rho's at various times
for q in range(t):
    L_0t = ( (gamma**0.5)*c + a*g(times[q], None) ) 
    I_0.append( (L_0t.dag() * L_0t * result_states.states[q]).tr() )

# %%
plt.figure() 
plt.plot(times, result.expect[0]) 
plt.plot(times, result.expect[1]) 
plt.plot(times, (np.cumsum(I_0)-I_0[0])*(times[1]-times[0]) )
plt.plot(times, (np.cumsum(I_0)-I_0[0])*(times[1]-times[0])+ result.expect[0]+result.expect[1])
plt.xlabel('Time') 
plt.ylabel('Expectation values') 
plt.legend(("atom excitation probability", "cavity photon number", "probability lost", "net probability")) 
#plt.plot([times[0], times[-1]], [result.expect[0][-1], result.expect[0][-1]],'--')
#plt.plot([times[0], times[-1]], [result.expect[1][-1], result.expect[1][-1]],'--')
plt.show()

# %% [markdown]
# ---
# ---
# # Calculating ideal $v(t)$ using correlation funtion:

# %%
times = np.linspace(0, t_final, t)
#make syre to set v(t), ie all coupling to zero for this
correlation = qutip.correlation_2op_2t(H, psi0, times, times, [L_0,], (gamma**0.5)*c.dag(), (gamma**0.5)*c)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-38-6bc7e97e53e2> in <module>
#       1 times = np.linspace(0, t_final, t)
#       2 #make syre to set v(t), ie all coupling to zero for this
# ----> 3 correlation = qutip.correlation_2op_2t(H, psi0, times, times, [L_0,], (gamma**0.5)*c.dag(), (gamma**0.5)*c)
#
# c:\Users\16yuk\anaconda3\lib\site-packages\qutip\correlation.py in correlation_2op_2t(H, state0, tlist, taulist, c_ops, a_op, b_op, solver, reverse, args, options)
#     219             C_op = b_op
#     220
# --> 221         return _correlation_2t(H, state0, tlist, taulist,
#     222                                c_ops, A_op, B_op, C_op,
#     223                                solver=solver, args=args, options=options)
#
# c:\Users\16yuk\anaconda3\lib\site-packages\qutip\correlation.py in _correlation_2t(H, state0, tlist, taulist, c_ops, a_op, b_op, c_op, solver, args, options)
#    1061
#    1062     if solver == "me":
# -> 1063         return _correlation_me_2t(H, state0, tlist, taulist,
#    1064                                   c_ops, a_op, b_op, c_op,
#    1065                                   args=args, options=options)
#
# c:\Users\16yuk\anaconda3\lib\site-packages\qutip\correlation.py in _correlation_me_2t(H, state0, tlist, taulist, c_ops, a_op, b_op, c_op, args, options)
#    1112             _args["_t0"] = tlist[t_idx]
#    1113
# -> 1114         corr_mat[t_idx, :] = mesolve(
#    1115             H_shifted, c_op * rho * a_op, taulist, c_ops_shifted,
#    1116             [b_op], args=_args, options=options
#
# c:\Users\16yuk\anaconda3\lib\site-packages\qutip\mesolve.py in mesolve(H, rho0, tlist, c_ops, e_ops, args, options, progress_bar, _safe_mode)
#     270         func(0., v, *ode_args) + v
#     271
# --> 272     res = _generic_ode_solve(func, ode_args, rho0, tlist, e_ops, options,
#     273                              progress_bar, dims=rho0.dims)
#     274     res.num_collapse = len(c_ops)
#
# c:\Users\16yuk\anaconda3\lib\site-packages\qutip\mesolve.py in _generic_ode_solve(func, ode_args, rho0, tlist, e_ops, opt, progress_bar, dims)
#     542
#     543         if t_idx < n_tsteps - 1:
# --> 544             r.integrate(r.t + dt[t_idx])
#     545
#     546     progress_bar.finished()
#
# c:\Users\16yuk\anaconda3\lib\site-packages\scipy\integrate\_ode.py in integrate(self, t, step, relax)
#     431
#     432         try:
# --> 433             self._y, self.t = mth(self.f, self.jac or (lambda: None),
#     434                                   self._y, self.t, t,
#     435                                   self.f_params, self.jac_params)
#
# c:\Users\16yuk\anaconda3\lib\site-packages\scipy\integrate\_ode.py in run(self, f, jac, y0, t0, t1, f_params, jac_params)
#    1005         args = ((f, jac, y0, t0, t1) + tuple(self.call_args) +
#    1006                 (f_params, jac_params))
# -> 1007         y1, t, istate = self.runner(*args)
#    1008         self.istate = istate
#    1009         if istate < 0:
#
# c:\Users\16yuk\anaconda3\lib\site-packages\qutip\cy\cqobjevo.pyx in qutip.cy.cqobjevo.CQobjEvo.mul_vec()
#
# c:\Users\16yuk\anaconda3\lib\site-packages\qutip\cy\cqobjevo.pyx in qutip.cy.cqobjevo.CQobjEvoTd._mul_vec()
#
# c:\Users\16yuk\anaconda3\lib\site-packages\qutip\cy\cqobjevo.pyx in qutip.cy.cqobjevo.CQobjEvo._factor_dyn()
#
# c:\Users\16yuk\anaconda3\lib\site-packages\qutip\cy\cqobjevo.pyx in qutip.cy.cqobjevo.CQobjEvo._factor()
#
# c:\Users\16yuk\anaconda3\lib\site-packages\qutip\qobjevo.py in __call__(self, t, args)
#    1846         out = []
#    1847         for func in self.funclist:
# -> 1848             out.append(func(t, now_args))
#    1849         return out
#    1850
#
# c:\Users\16yuk\anaconda3\lib\site-packages\qutip\qobjevo.py in __call__(self, t, args)
#    1874
#    1875     def __call__(self, t, args):
# -> 1876         return np.conj(self.func(t, args))
#    1877
#    1878
#
# c:\Users\16yuk\anaconda3\lib\site-packages\qutip\correlation.py in <lambda>(t, args_i)
#    1360                 return op(t + args_i["_t0"], args_i)
#    1361             fn = lambda t, args_i: \
# -> 1362                 op(t + args_i["_t0"], args_i)
#    1363         else:
#    1364             def fn(t, args_i):
#
# <ipython-input-33-1da5ed8eb553> in g(t, args)
#      10 #Defining the time dependent coupling
#      11 def g(t, args):
# ---> 12   integral = quad(v_2, 0, t)[0]
#      13   if integral == 0:
#      14     return 0
#
# c:\Users\16yuk\anaconda3\lib\site-packages\scipy\integrate\quadpack.py in quad(func, a, b, args, full_output, epsabs, epsrel, limit, points, weight, wvar, wopts, maxp1, limlst)
#     349
#     350     if weight is None:
# --> 351         retval = _quad(func, a, b, args, full_output, epsabs, epsrel, limit,
#     352                        points)
#     353     else:
#
# c:\Users\16yuk\anaconda3\lib\site-packages\scipy\integrate\quadpack.py in _quad(func, a, b, args, full_output, epsabs, epsrel, limit, points)
#     461     if points is None:
#     462         if infbounds == 0:
# --> 463             return _quadpack._qagse(func,a,b,args,full_output,epsabs,epsrel,limit)
#     464         else:
#     465             return _quadpack._qagie(func,bound,infbounds,args,full_output,epsabs,epsrel,limit)
#
# <ipython-input-33-1da5ed8eb553> in v_2(t)
#       6 #Defining |v(t)|^2
#       7 def v_2(t):
# ----> 8   return np.conj(v(t))*v(t)
#       9
#      10 #Defining the time dependent coupling
#
# <ipython-input-33-1da5ed8eb553> in v(t, args)
#       1 #Defining the shape of the output pulse as a function of time
#       2 def v(t,args=None):
# ----> 3   return np.sqrt(gamma)*np.exp(-t*gamma/2)
#       4   #return 0
#       5
#
# KeyboardInterrupt:

# %%
plt.matshow(np.real(correlation))
plt.colorbar()
#plotting v(t) vs v(t+tau)

# %%
plt.plot(np.real(correlation.T)[0]/np.real(correlation[0])[0], 'r')
plt.plot(range(t), [np.exp(-times[x]*gamma) for x in range(t)], '.')
plt.legend(("v(2t)", "fitted function"))

# %%
plt.plot(np.real(correlation)[0]/np.real(correlation[0])[0], 'r')
plt.plot(range(t), [np.exp(-times[x]*gamma/2) for x in range(t)], '.')
plt.legend(("v(tau)", "fitted function"))

# %% [markdown]
# ---
# ---

# %% [markdown]
# # Archived testing code:

# %%
g = 0.3
n = 100
times = np.linspace(0, 20, n)

#testing out the propogator 
rx, ry, rz = [2,1,-1]
norm = (rx**2 + ry**2 + rz**2 )**0.5 
rx = rx/norm
ry = ry/norm
rz = rz/norm

rho_0 = 0.5*(qutip.qeye(2) + (rz*qutip.sigmaz()) + (ry*qutip.sigmay()) + (rx*qutip.sigmax()))
#qutip.fock(2,1).full()

d = qutip.destroy(2)

#result = qutip.mesolve(qutip.qeye(2), rho_0, times, [(g**0.5)*d], [d,])         # H, rho(0), times, collapse op, obserbables

# %%
cor = qutip.correlation_2op_2t(qutip.qeye(2), rho_0, times, times, [(g**0.5)*d,], d, qutip.qeye(2))
plt.matshow(np.real(cor))
plt.colorbar()

# %%
plt.figure() 

plt.plot(times, result.expect[0]) 
plt.plot(times, [0.5*(1-rz)*np.exp(-x*gamma) for x in times], '.')
'''
plt.plot(times, np.imag(result.expect[0]) ) 
plt.plot(times, [0.5*(-ry)*np.exp(-x*gamma*0.5) for x in times], '.')
'''
